# %% [markdown]
# <a href="https://colab.research.google.com/github/yalini154/1/blob/main/understanding_about_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-1b3438c8-b0b7-4cef-8346-6b9740a7286c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b3438c8-b0b7-4cef-8346-6b9740a7286c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Titanic = pd.read_csv(r"titanic.csv", sep='\t')
Titanic.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %%
Titanic.shape
# Out:
# (156, 1)

# %%
Titanic.isnull().sum()
# Out:
# PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked    0
# dtype: int64

# %%
sns.heatmap(Titanic.isnull(), cmap="spring")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# <Axes: >
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
Titanic.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %%
Titanic.drop("deck", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1291/203389281.py in <cell line: 0>()
# ----> 1 Titanic.drop("deck", axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
Titanic.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %%
Titanic.dropna(inplace=True)

# %%
sns.heatmap(Titanic.isnull(), cbar=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# <Axes: >
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pd.get_dummies(Titanic["embarked"], drop_frist=True).head()

# %%
arked = pd.get_dummies(Titanic["embarked"], drop_frist=True)

# %%
pclass = pd.get_dummies(Titanic["pclass"], drop_frist=True)

# %%
pclass.head(4)

# %%
Titanic.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
