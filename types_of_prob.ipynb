# %% [markdown]
# <a href="https://colab.research.google.com/github/yalini154/1/blob/main/types_of_prob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as stats

prob = 1 - stats.binom.cdf(6, 10, 0.5)

print("the probability of getting more than 6heads in 10 coin filps is :", prob)



import scipy.stats as stats

prob1 = stats.poisson.pmf(6, 10)
print("probability of raining for exactly 6 days :", prob1)

prob2 = stats.poisson.pmf(12, 10) + stats.poisson.pmf(13, 10) + stats.poisson.pmf(14, 10)
print("probability of raining for 12-14 days :", prob2)


import scipy.stats as stats

prob1 = 1-stats.poisson.cdf(20, 15)


print(prob1)


prob2 = stats.poisson.cdf(21, 15) - stats.poisson.cdf(16, 15)

print(prob2)
# Out:
# the probability of getting more than 6heads in 10 coin filps is : 0.171875
# probability of raining for exactly 6 days : 0.06305545800345125
# probability of raining for 12-14 days : 0.21976538076223123
# 0.08297091003146029
# 0.2827703929341844
