# %% [markdown]
# <a href="https://colab.research.google.com/github/yalini154/1/blob/main/study_of_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %%
diabetes_X_train = diabetes_X[:-5]
diabetes_X_test = diabetes_X[-5:]

# %%
diabetes_y_train = diabetes_y[:-5]
diabetes_y_test = diabetes_y[-5:]

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [1052.85763083]

# %%
print('Mean squared error: %.2f')
# Out:
# Mean squared error: %.2f

# %%
print('Coefficients of determination: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients of determination: 0.54

# %%
plt.scatter(diabetes_X_test, diabetes_y_test, color='black')

# %%
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)
