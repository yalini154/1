# %% [markdown]
# <a href="https://colab.research.google.com/github/yalini154/1/blob/main/condition_probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def a_and_b(a, b):

  if a==1:
    prob_student = 0.3
    if b ==1:
      prob_dining = 0.75
    else:
      prob_dining = 0.25
    print("Probability of a given b:", prob_dining)

  if a==2:
    prob_student=0.7
    if b==1:
      prob_dining = 0.6
    else:
      prob_dining = 0.4
    print("Probability of a given b:", prob_dining)

  prob_a_and_b = prob_student*prob_dining
  return round(prob_a_and_b, 3)

print("Check the probability of any event occuring. first enter your choices")

print("Is the student a freshman? \n 1. Yes \n 2. No")
a = int(input("Enter your choice(1/2): "))

print("Is student eating in the dining hall? \n 1. Yes \n 2. No")
b = int(input("Enter your choice(1/2): "))

print("Here is the probability of both the events occuring :", a_and_b(a, b))
# Out:
# Check the probability of any event occuring. first enter your choices
# Is the student a freshman?
#  1. Yes
#  2. No
# Enter your choice(1/2): 2
# Is student eating in the dining hall?
#  1. Yes
#  2. No
# Enter your choice(1/2): 2
# Probability of a given b: 0.4
# Here is the probability of both the events occuring : 0.28

# %%
def prob_a_and_b(a, b, total):
  prob_a = orange/total

  prob_bga = blue/(total-1)

  prob_AandB = prob_a * prob_bga

  return round(prob_AandB,3)

orange = int(input("Enter the number of orange balls"))
blue = int(input("Enter the number of blue balls"))
total = orange+blue

print('probability of Getting 1st orange and 2nd blue ball: ')
print(prob_a_and_b(orange, blue, total))
# Out:
# Enter the number of orange balls4
# Enter the number of blue balls13
# probability of Getting 1st orange and 2nd blue ball:
# 0.191

# %%
RS = int(input("Enter the number of red shirts"))
BS = int(input("Enter the number of blue shirts"))
WS = int(input("Enter the number of white shirts"))
total = RS+BS+WS

prob_a = BS/total
prob_b = RS/total

prob_bga = BS/total
prob_a_and_b = prob_a*prob_b

print(round((prob_bga),3))
print(round((prob_a_and_b),3))
# Out:
# Enter the number of red shirts6
# Enter the number of blue shirts8
# Enter the number of white shirts4
# 0.444
# 0.148
