# %% [markdown]
# <a href="https://colab.research.google.com/github/yalini154/1/blob/main/DSCM11L1A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Question 1**
# ##### Have a look at this picture and give your answer what is the type of this database?
#
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Just run this code snippet and enter your answer**

# %%
print("What is the type of above given database -\n 1)Relational Database \n 2)Non-Relational Database")
answer = int(input("Enter your guess here..."))
if answer == 2:
  print("You guessed it right!")
else:
  print("Unfortunately your guess was wrong.")

print("\nPlease tell your mentor why you guessed this?")
# Out:
# What is the type of above given database -
#  1)Relational Database
#  2)Non-Relational Database
# Enter your guess here...2
# You guessed it right!
#
# Please tell your mentor why you guessed this?

# %% [markdown]
# #### **Question 2**
# ##### Have a look at this picture and give your answer what is the type of this database?
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# **Just run this code snippet and enter your answer**

# %%
print("What is the type of above given database -\n 1)Relational Database \n 2)Non-Relational Database")
answer = int(input("Enter your guess here..."))
if answer == 1:
  print("You guessed it right!")
else:
  print("Unfortunately your guess was wrong.")

print("\nPlease tell your mentor why you guessed this?")
# Out:
# What is the type of above given database -
#  1)Relational Database
#  2)Non-Relational Database
# Enter your guess here...1
# You guessed it right!
#
# Please tell your mentor why you guessed this?
